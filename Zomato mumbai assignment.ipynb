# %%
# !pip install plotly
# !pip install -U kaleido
# Out:
# Collecting plotly
#   Downloading https://files.pythonhosted.org/packages/a8/07/72953cf70e3bd3a24cbc3e743e6f8539abe6e3e6d83c3c0c83426eaffd39/plotly-5.18.0-py3-none-any.whl (15.6MB)
# Requirement already satisfied: packaging in c:\users\poorn\anaconda3\lib\site-packages (from plotly) (19.2)
# Collecting tenacity>=6.2.0 (from plotly)
#   Downloading https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\poorn\anaconda3\lib\site-packages (from packaging->plotly) (2.4.2)
# Requirement already satisfied: six in c:\users\poorn\anaconda3\lib\site-packages (from packaging->plotly) (1.12.0)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.18.0 tenacity-8.2.3
# Collecting kaleido
#   Downloading https://files.pythonhosted.org/packages/f7/9a/0408b02a4bcb3cf8b338a2b074ac7d1b2099e2b092b42473def22f7b625f/kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9MB)
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "svg"

# %% [markdown]
# # 2. Importing the dataset

# %%
raw_df=pd.read_csv('Zomato_Mumbai_Dataset.csv', delimiter='|')

# %%
#raw_df

# %%
raw_df.describe()
# Out:
#          NAME  PRICE  CUSINE_CATEGORY    CITY  REGION    URL  PAGE NO  \
# count   15081  15080            15079   15080   15080  15080    15080
# unique  12720     67             3183       2     241  13823      944
# top      NAME    400  CUSINE_CATEGORY  Mumbai  REGION    URL  PAGE NO
# freq      942   2042              942   14138     942    942      942
#
#         CUSINE TYPE                 TIMING RATING_TYPE RATING  VOTES
# count         15080                  15015       14070  15080  15080
# unique           23                   2551          31     35   1124
# top     Quick Bites  11am to 11pm(Mon-Sun)     Average      -      -
# freq           5262                   1192        5112   2360   2360

# %%
raw_df.count()
# Out:
# NAME               15081
# PRICE              15080
# CUSINE_CATEGORY    15079
# CITY               15080
# REGION             15080
# URL                15080
# PAGE NO            15080
# CUSINE TYPE        15080
# TIMING             15015
# RATING_TYPE        14070
# RATING             15080
# VOTES              15080
# dtype: int64

# %%
raw_df.head()
# Out:
#              NAME PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800                                      Asian,Chinese
# 3  Butterfly High  1000                                      Modern Indian
# 4       BKC  DIVE  1200                   North Indian,Chinese,Continental
#
#      CITY                                             REGION  \
# 0  Mumbai  First International Financial Centre-- Bandra ...
# 1  Mumbai                                              Mahim
# 2  Mumbai                                               Juhu
# 3  Mumbai                               Bandra Kurla Complex
# 4  Mumbai                               Bandra Kurla Complex
#
#                                                  URL PAGE NO     CUSINE TYPE  \
# 0  https://www.zomato.com/mumbai/hitchki-bandra-k...       1   Casual Dining
# 1  https://www.zomato.com/mumbai/baba-falooda-mah...       1  Dessert Parlor
# 2  https://www.zomato.com/mumbai/chin-chin-chu-ju...       1   Casual Dining
# 3  https://www.zomato.com/mumbai/butterfly-high-b...       1             Bar
# 4  https://www.zomato.com/mumbai/bkc-dive-bandra-...       1             Bar
#
#                      TIMING  RATING_TYPE RATING VOTES
# 0  12noon to 130am(Mon-Sun)    Excellent    4.9  3529
# 1       2pm to 1am(Mon-Sun)    Very Good    4.4  1723
# 2    12noon to 1am(Mon-Sun)    Very Good    4.2   337
# 3  12noon to 130am(Mon-Sun)    Very Good    4.3  1200
# 4    1130am to 1am(Mon-Sun)  Veľmi dobré    4.4  5995

# %% [markdown]
# # 3. Getting Basic Information about the Dataset

# %%
raw_df.shape
# Out:
# (15081, 12)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15081 entries, 0 to 15080
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             15081 non-null  object
#  1   PRICE            15080 non-null  object
#  2   CUSINE_CATEGORY  15079 non-null  object
#  3   CITY             15080 non-null  object
#  4   REGION           15080 non-null  object
#  5   URL              15080 non-null  object
#  6   PAGE NO          15080 non-null  object
#  7   CUSINE TYPE      15080 non-null  object
#  8   TIMING           15015 non-null  object
#  9   RATING_TYPE      14070 non-null  object
#  10  RATING           15080 non-null  object
#  11  VOTES            15080 non-null  object
# dtypes: object(12)
# memory usage: 1.4+ MB

# %% [markdown]
# # cleaning the dataset
# ## a. Removing the redundunt rows of data

# %%
# Checking redundunt rows of data
wrong_data = raw_df['PAGE NO'] == 'PAGE NO'
raw_df[wrong_data]
# Out:
#        NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE  \
# 15     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 31     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 47     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 63     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 79     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# ...     ...    ...              ...   ...     ...  ...      ...          ...
# 15000  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15016  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15032  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15048  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15064  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
#
#        TIMING  RATING_TYPE  RATING  VOTES
# 15     TIMING  RATING_TYPE  RATING  VOTES
# 31     TIMING  RATING_TYPE  RATING  VOTES
# 47     TIMING  RATING_TYPE  RATING  VOTES
# 63     TIMING  RATING_TYPE  RATING  VOTES
# 79     TIMING  RATING_TYPE  RATING  VOTES
# ...       ...          ...     ...    ...
# 15000  TIMING  RATING_TYPE  RATING  VOTES
# 15016  TIMING  RATING_TYPE  RATING  VOTES
# 15032  TIMING  RATING_TYPE  RATING  VOTES
# 15048  TIMING  RATING_TYPE  RATING  VOTES
# 15064  TIMING  RATING_TYPE  RATING  VOTES
#
# [942 rows x 12 columns]

# %%
raw_df=raw_df[~wrong_data]

# %%
raw_df
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15076  Hari Om Snack Bar   350
# 15077           PitaBurg   400
# 15078     Uncha Otlawala   300
# 15079     Mandarin Panda   400
# 15080                     NaN
#
#                                          CUSINE_CATEGORY    CITY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...  Mumbai
# 1                           Desserts,Ice Cream,Beverages  Mumbai
# 2                                          Asian,Chinese  Mumbai
# 3                                          Modern Indian  Mumbai
# 4                       North Indian,Chinese,Continental  Mumbai
# ...                                                  ...     ...
# 15076                     Fast Food,South Indian,Chinese  Mumbai
# 15077                                 Fast Food,Lebanese  Mumbai
# 15078                                 Desserts,Ice Cream  Mumbai
# 15079                              Desserts,Chinese,Thai  Mumbai
# 15080                                                NaN     NaN
#
#                                                   REGION  \
# 0      First International Financial Centre-- Bandra ...
# 1                                                  Mahim
# 2                                                   Juhu
# 3                                   Bandra Kurla Complex
# 4                                   Bandra Kurla Complex
# ...                                                  ...
# 15076                                     Kandivali West
# 15077                                        Lower Parel
# 15078                                     Kandivali West
# 15079                                         Malad West
# 15080                                                NaN
#
#                                                      URL PAGE NO  \
# 0      https://www.zomato.com/mumbai/hitchki-bandra-k...       1
# 1      https://www.zomato.com/mumbai/baba-falooda-mah...       1
# 2      https://www.zomato.com/mumbai/chin-chin-chu-ju...       1
# 3      https://www.zomato.com/mumbai/butterfly-high-b...       1
# 4      https://www.zomato.com/mumbai/bkc-dive-bandra-...       1
# ...                                                  ...     ...
# 15076  https://www.zomato.com/mumbai/hari-om-snack-ba...      99
# 15077  https://www.zomato.com/mumbai/pitaburg-lower-p...      99
# 15078  https://www.zomato.com/mumbai/uncha-otlawala-1...      99
# 15079  https://www.zomato.com/mumbai/mandarin-panda-m...      99
# 15080                                                NaN     NaN
#
#           CUSINE TYPE                                         TIMING  \
# 0       Casual Dining                       12noon to 130am(Mon-Sun)
# 1      Dessert Parlor                            2pm to 1am(Mon-Sun)
# 2       Casual Dining                         12noon to 1am(Mon-Sun)
# 3                 Bar                       12noon to 130am(Mon-Sun)
# 4                 Bar                         1130am to 1am(Mon-Sun)
# ...               ...                                            ...
# 15076     Quick Bites                         11am to 230am(Mon-Sun)
# 15077            none  11am to 11pm(Mon,Tue,Wed,Thu,Sun),11am to ...
# 15078  Dessert Parlor                         9am to 1230AM(Mon-Sun)
# 15079            none            12noon to 330pm,7pm to 1am(Mon-Sun)
# 15080             NaN                                            NaN
#
#        RATING_TYPE RATING VOTES
# 0        Excellent    4.9  3529
# 1        Very Good    4.4  1723
# 2        Very Good    4.2   337
# 3        Very Good    4.3  1200
# 4      Veľmi dobré    4.4  5995
# ...            ...    ...   ...
# 15076         Good    3.7    64
# 15077      Average    3.4    99
# 15078         Good    3.5    29
# 15079         Good    3.7   121
# 15080          NaN    NaN   NaN
#
# [14139 rows x 12 columns]

# %%
raw_df.drop(['URL','PAGE NO', 'CITY'],axis=1,inplace=True)

# %%
raw_df.head()
# Out:
#              NAME PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800                                      Asian,Chinese
# 3  Butterfly High  1000                                      Modern Indian
# 4       BKC  DIVE  1200                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#                      TIMING  RATING_TYPE RATING VOTES
# 0  12noon to 130am(Mon-Sun)    Excellent    4.9  3529
# 1       2pm to 1am(Mon-Sun)    Very Good    4.4  1723
# 2    12noon to 1am(Mon-Sun)    Very Good    4.2   337
# 3  12noon to 130am(Mon-Sun)    Very Good    4.3  1200
# 4    1130am to 1am(Mon-Sun)  Veľmi dobré    4.4  5995

# %% [markdown]
# # Remove Null Records

# %%
raw_df.isna().sum()
# Out:
# NAME                  0
# PRICE                 1
# CUSINE_CATEGORY       2
# REGION                1
# CUSINE TYPE           1
# TIMING               66
# RATING_TYPE        1011
# RATING                1
# VOTES                 1
# dtype: int64

# %%
raw_df[raw_df['PRICE'].isnull()]
# Out:
#       NAME PRICE CUSINE_CATEGORY REGION CUSINE TYPE TIMING RATING_TYPE RATING  \
# 15080       NaN             NaN    NaN         NaN    NaN         NaN    NaN
#
#       VOTES
# 15080   NaN

# %%
#raw_df=raw_df.drop(labels=15080,axis=0)

# %%
raw_df.isna().sum()
# Out:
# NAME                  0
# PRICE                 1
# CUSINE_CATEGORY       2
# REGION                1
# CUSINE TYPE           1
# TIMING               66
# RATING_TYPE        1011
# RATING                1
# VOTES                 1
# dtype: int64

# %%
raw_df.fillna('NA',inplace=True)

# %%
raw_df.isna().sum()
# Out:
# NAME               0
# PRICE              0
# CUSINE_CATEGORY    0
# REGION             0
# CUSINE TYPE        0
# TIMING             0
# RATING_TYPE        0
# RATING             0
# VOTES              0
# dtype: int64

# %% [markdown]
# # converting the data column to numeric datatypes

# %%
# Checking for text values in the column before converting it to numeric datatype
raw_df['RATING'].value_counts()
# Out:
# RATING
# -          2360
# 3.5        1094
# 3.4        1036
# 3.6         960
# NEW         953
# 3.3         926
# 3.7         917
# 3.2         801
# 3.8         782
# 3.1         734
# 3.0         622
# 3.9         596
# 2.9         409
# 4.0         408
# 2.8         309
# 4.1         298
# 4.2         199
# 2.7         170
# 4.3         148
# 4.4          99
# 2.6          77
# Opening      57
# 4.5          46
# 2.5          39
# 4.6          32
# 2.4          26
# 4.7          13
# 2.3          10
# 2.1           5
# 2.2           4
# 4.8           4
# 4.9           2
# 1.8           1
# 2.0           1
# NA            1
# Name: count, dtype: int64

# %%
raw_df['RATING'].replace(to_replace=['-','NEW','Opening','NA'],value=0,inplace=True)
# Replacing the text values with '0'

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14139 entries, 0 to 15080
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             14139 non-null  object
#  1   PRICE            14139 non-null  object
#  2   CUSINE_CATEGORY  14139 non-null  object
#  3   REGION           14139 non-null  object
#  4   CUSINE TYPE      14139 non-null  object
#  5   TIMING           14139 non-null  object
#  6   RATING_TYPE      14139 non-null  object
#  7   RATING           14139 non-null  object
#  8   VOTES            14139 non-null  object
# dtypes: object(9)
# memory usage: 1.1+ MB

# %%
raw_df['PRICE'].replace(to_replace=['-','NEW','Opening','NA'],value=0,inplace=True)
raw_df['PRICE'].value_counts()
# Out:
# PRICE
# 400     2042
# 500     1954
# 300     1936
# 200     1177
# 600     1062
#         ...
# 5000       1
# 398        1
# 3500       1
# 1550       1
# 0          1
# Name: count, Length: 67, dtype: int64

# %%
raw_df['VOTES'].value_counts()
# Out:
# VOTES
# -       2360
# NEW      953
# 4        364
# 5        320
# 6        288
#         ...
# 1029       1
# 7350       1
# 964        1
# 585        1
# NA         1
# Name: count, Length: 1124, dtype: int64

# %%
raw_df['VOTES'].replace(to_replace=['-','NEW','Opening','NA'],value=0,inplace=True)
raw_df['VOTES'].value_counts()
# Out:
# VOTES
# 0       3371
# 4        364
# 5        320
# 6        288
# 7        277
#         ...
# 1029       1
# 7350       1
# 964        1
# 585        1
# 1249       1
# Name: count, Length: 1121, dtype: int64

# %%
raw_df['RATING']=raw_df['RATING'].astype('float64')
raw_df['PRICE']=raw_df['PRICE'].astype('float64')
raw_df['VOTES']=raw_df['VOTES'].astype('int64')

# %%
raw_df['VOTES'].replace(to_replace=['-','NEW','Opening'],value=0,inplace=True)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14139 entries, 0 to 15080
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             14139 non-null  object
#  1   PRICE            14139 non-null  float64
#  2   CUSINE_CATEGORY  14139 non-null  object
#  3   REGION           14139 non-null  object
#  4   CUSINE TYPE      14139 non-null  object
#  5   TIMING           14139 non-null  object
#  6   RATING_TYPE      14139 non-null  object
#  7   RATING           14139 non-null  float64
#  8   VOTES            14139 non-null  int64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# # Working on Timing Column

# %%
raw_df['TIMING'].value_counts()
# Out:
# TIMING
# 11am to 11pm(Mon-Sun)                              1192
# 11am to 12midnight(Mon-Sun)                         632
# 12noon to 12midnight(Mon-Sun)                       467
# 11am to 1130pm(Mon-Sun)                             309
# 10am to 10pm(Mon-Sun)                               267
#                                                    ...
# 1130am to 4pm,630pm to 1230AM...                      1
# 12midnight to 5am,12noon to 12midnight(Mon-Sun)       1
# 12midnight to 1230AM,12noon to 4pm,7pm to ...         1
# 12noon to 330pm,630pm to 12midnight...                1
# 8am to 11pm,12midnight to 115am(Mon-Sun)              1
# Name: count, Length: 2551, dtype: int64

# %%
#splitting the column
temp_df=raw_df['TIMING'].str.split('(',n=1,expand=True)
temp_df
# Out:
#                                 0                                 1
# 0                 12noon to 130am                          Mon-Sun)
# 1                      2pm to 1am                          Mon-Sun)
# 2                   12noon to 1am                          Mon-Sun)
# 3                 12noon to 130am                          Mon-Sun)
# 4                   1130am to 1am                          Mon-Sun)
# ...                           ...                               ...
# 15076               11am to 230am                          Mon-Sun)
# 15077                11am to 11pm  Mon,Tue,Wed,Thu,Sun),11am to ...
# 15078               9am to 1230AM                          Mon-Sun)
# 15079  12noon to 330pm,7pm to 1am                          Mon-Sun)
# 15080                          NA                              None
#
# [14139 rows x 2 columns]

# %%
raw_df['Timing']=temp_df[0]
raw_df['DAYS_OPEN']=temp_df[1]
raw_df.head()
# Out:
#              NAME   PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200.0  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400.0                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800.0                                      Asian,Chinese
# 3  Butterfly High  1000.0                                      Modern Indian
# 4       BKC  DIVE  1200.0                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#                      TIMING  RATING_TYPE  RATING  VOTES           Timing  \
# 0  12noon to 130am(Mon-Sun)    Excellent     4.9   3529  12noon to 130am
# 1       2pm to 1am(Mon-Sun)    Very Good     4.4   1723       2pm to 1am
# 2    12noon to 1am(Mon-Sun)    Very Good     4.2    337    12noon to 1am
# 3  12noon to 130am(Mon-Sun)    Very Good     4.3   1200  12noon to 130am
# 4    1130am to 1am(Mon-Sun)  Veľmi dobré     4.4   5995    1130am to 1am
#
#   DAYS_OPEN
# 0  Mon-Sun)
# 1  Mon-Sun)
# 2  Mon-Sun)
# 3  Mon-Sun)
# 4  Mon-Sun)

# %%
# Removing the bracket character from Days column

raw_df['DAYS_OPEN'] = raw_df['DAYS_OPEN'].str.replace(r'\)', '', regex=True)
raw_df.head()
# Out:
#              NAME   PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200.0  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400.0                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800.0                                      Asian,Chinese
# 3  Butterfly High  1000.0                                      Modern Indian
# 4       BKC  DIVE  1200.0                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#                      TIMING  RATING_TYPE  RATING  VOTES           Timing  \
# 0  12noon to 130am(Mon-Sun)    Excellent     4.9   3529  12noon to 130am
# 1       2pm to 1am(Mon-Sun)    Very Good     4.4   1723       2pm to 1am
# 2    12noon to 1am(Mon-Sun)    Very Good     4.2    337    12noon to 1am
# 3  12noon to 130am(Mon-Sun)    Very Good     4.3   1200  12noon to 130am
# 4    1130am to 1am(Mon-Sun)  Veľmi dobré     4.4   5995    1130am to 1am
#
#   DAYS_OPEN
# 0   Mon-Sun
# 1   Mon-Sun
# 2   Mon-Sun
# 3   Mon-Sun
# 4   Mon-Sun

# %%
raw_df.isnull().sum()
# Out:
# NAME                 0
# PRICE                0
# CUSINE_CATEGORY      0
# REGION               0
# CUSINE TYPE          0
# TIMING               0
# RATING_TYPE          0
# RATING               0
# VOTES                0
# Timing               0
# DAYS_OPEN          161
# dtype: int64

# %%
raw_df.fillna('NA', inplace=True)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14139 entries, 0 to 15080
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             14139 non-null  object
#  1   PRICE            14139 non-null  float64
#  2   CUSINE_CATEGORY  14139 non-null  object
#  3   REGION           14139 non-null  object
#  4   CUSINE TYPE      14139 non-null  object
#  5   TIMING           14139 non-null  object
#  6   RATING_TYPE      14139 non-null  object
#  7   RATING           14139 non-null  float64
#  8   VOTES            14139 non-null  int64
#  9   Timing           14139 non-null  object
#  10  DAYS_OPEN        14139 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 1.3+ MB

# %%
useless_data = (raw_df['RATING'] == 0.0) | (raw_df['VOTES'] == 0)
raw_df[useless_data]
# Out:
#                                 NAME  PRICE  \
# 32     Hotel Annapoorna Refreshments  400.0
# 34                         Biryani 9  600.0
# 36                 D Fusion Flavours  350.0
# 39                      Nation Tadka  400.0
# 83              Link  Way Restaurant  500.0
# ...                              ...    ...
# 14999                       Khansama    0.0
# 15010        Earth Cafe @ Waterfield  800.0
# 15023           How About Some Cream  200.0
# 15046          Food And Taste Theory  800.0
# 15080                                  0.0
#
#                                    CUSINE_CATEGORY  \
# 32                   Maharashtrian,Mughlai,Chinese
# 34                            Biryani,North Indian
# 36                                         Chinese
# 39     North Indian,South Indian,Chinese,Fast Food
# 83                            North Indian,Chinese
# ...                                            ...
# 14999                                      Biryani
# 15010    Cafe,Healthy Food,Italian,Pizza,Beverages
# 15023                                    Beverages
# 15046                          Continental,Italian
# 15080                                           NA
#
#                            REGION    CUSINE TYPE  \
# 32                       Ghansoli    Quick Bites
# 34      Near Andheri East Station           none
# 36                  Goregaon East           none
# 39                          Worli           none
# 83                     Jogeshwari    Quick Bites
# ...                           ...            ...
# 14999                 Lower Parel           none
# 15010  Linking Road-- Bandra West           Café
# 15023              Mumbai Central  Beverage Shop
# 15046  Phoenix Marketcity-- Kurla  Casual Dining
# 15080                          NA             NA
#
#                                                   TIMING RATING_TYPE  RATING  \
# 32                             1030am to 1230AM(Mon-Sun)   Not rated     0.0
# 34                                  11am to 3am(Mon-Sun)          NA     0.0
# 36                   12noon to 330pm,7pm to 3am(Mon-Sun)          NA     0.0
# 39                             12noon to 1230AM(Mon-Sun)   Not rated     0.0
# 83                     12noon to 4pm,8pm to 1am(Mon-Sun)   Not rated     0.0
# ...                                                  ...         ...     ...
# 14999                             12noon to 3am(Mon-Sun)          NA     0.0
# 15010        10am to 10pm(Mon-Thu),10am to 11pm(Fri-Sun)          NA     0.0
# 15023                             12noon to 3am(Mon-Sun)          NA     0.0
# 15046  9am to 12midnight(Mon-Fri),9am to 1230AM(Sat-Sun)          NA     0.0
# 15080                                                 NA          NA     0.0
#
#        VOTES                      Timing                      DAYS_OPEN
# 32         0            1030am to 1230AM                        Mon-Sun
# 34         0                 11am to 3am                        Mon-Sun
# 36         0  12noon to 330pm,7pm to 3am                        Mon-Sun
# 39         0            12noon to 1230AM                        Mon-Sun
# 83         0    12noon to 4pm,8pm to 1am                        Mon-Sun
# ...      ...                         ...                            ...
# 14999      0               12noon to 3am                        Mon-Sun
# 15010      0                10am to 10pm   Mon-Thu,10am to 11pm(Fri-Sun
# 15023      0               12noon to 3am                        Mon-Sun
# 15046      0           9am to 12midnight  Mon-Fri,9am to 1230AM(Sat-Sun
# 15080      0                          NA                             NA
#
# [3372 rows x 11 columns]

# %%
## Performing Negation of the useless dataset and then storing the correct data back in the raw_df DataFrame
## This permamnently remove the wrong data from the original dataframe
raw_df = raw_df[~useless_data]
raw_df
# Out:
#                     NAME   PRICE  \
# 0                Hitchki  1200.0
# 1           Baba Falooda   400.0
# 2          Chin Chin Chu  1800.0
# 3         Butterfly High  1000.0
# 4              BKC  DIVE  1200.0
# ...                  ...     ...
# 15075    Tirupati Balaji   500.0
# 15076  Hari Om Snack Bar   350.0
# 15077           PitaBurg   400.0
# 15078     Uncha Otlawala   300.0
# 15079     Mandarin Panda   400.0
#
#                                          CUSINE_CATEGORY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...
# 1                           Desserts,Ice Cream,Beverages
# 2                                          Asian,Chinese
# 3                                          Modern Indian
# 4                       North Indian,Chinese,Continental
# ...                                                  ...
# 15075                     Chinese,Fast Food,North Indian
# 15076                     Fast Food,South Indian,Chinese
# 15077                                 Fast Food,Lebanese
# 15078                                 Desserts,Ice Cream
# 15079                              Desserts,Chinese,Thai
#
#                                                   REGION     CUSINE TYPE  \
# 0      First International Financial Centre-- Bandra ...   Casual Dining
# 1                                                  Mahim  Dessert Parlor
# 2                                                   Juhu   Casual Dining
# 3                                   Bandra Kurla Complex             Bar
# 4                                   Bandra Kurla Complex             Bar
# ...                                                  ...             ...
# 15075                            Oshiwara-- Andheri West   Casual Dining
# 15076                                     Kandivali West     Quick Bites
# 15077                                        Lower Parel            none
# 15078                                     Kandivali West  Dessert Parlor
# 15079                                         Malad West            none
#
#                                               TIMING  RATING_TYPE  RATING  \
# 0                           12noon to 130am(Mon-Sun)    Excellent     4.9
# 1                                2pm to 1am(Mon-Sun)    Very Good     4.4
# 2                             12noon to 1am(Mon-Sun)    Very Good     4.2
# 3                           12noon to 130am(Mon-Sun)    Very Good     4.3
# 4                             1130am to 1am(Mon-Sun)  Veľmi dobré     4.4
# ...                                              ...          ...     ...
# 15075       8am to 11pm,12midnight to 115am(Mon-Sun)         Good     3.5
# 15076                         11am to 230am(Mon-Sun)         Good     3.7
# 15077  11am to 11pm(Mon,Tue,Wed,Thu,Sun),11am to ...      Average     3.4
# 15078                         9am to 1230AM(Mon-Sun)         Good     3.5
# 15079            12noon to 330pm,7pm to 1am(Mon-Sun)         Good     3.7
#
#        VOTES                           Timing                        DAYS_OPEN
# 0       3529                  12noon to 130am                          Mon-Sun
# 1       1723                       2pm to 1am                          Mon-Sun
# 2        337                    12noon to 1am                          Mon-Sun
# 3       1200                  12noon to 130am                          Mon-Sun
# 4       5995                    1130am to 1am                          Mon-Sun
# ...      ...                              ...                              ...
# 15075    267  8am to 11pm,12midnight to 115am                          Mon-Sun
# 15076     64                    11am to 230am                          Mon-Sun
# 15077     99                     11am to 11pm  Mon,Tue,Wed,Thu,Sun,11am to ...
# 15078     29                    9am to 1230AM                          Mon-Sun
# 15079    121       12noon to 330pm,7pm to 1am                          Mon-Sun
#
# [10767 rows x 11 columns]

# %% [markdown]
# # Working on 'RATING_TYPE' Column

# %%
#Checking the unique values in the column
raw_df['RATING_TYPE'].value_counts()
# Out:
# RATING_TYPE
# Average          5111
# Good             4330
# Very Good        1137
# Excellent          95
# Poor               47
# Veľmi dobré         6
# Skvělá volba        4
# Dobrze              4
# Bardzo dobrze       3
# Ortalama            2
# Bueno               2
# İyi                 2
# Buono               2
# Dobré               2
# Bom                 2
# Priemer             2
# Průměr              2
# Muito Bom           2
# Promedio            2
# Muy Bueno           1
# Sangat Baik         1
# Média               1
# Biasa               1
# Skvělé              1
# Baik                1
# Çok iyi             1
# Excelente           1
# Velmi dobré         1
# Media               1
# Name: count, dtype: int64

# %%
raw_df['RATING_TYPE'].replace(to_replace='Excelente' , value='Excellent', inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['Veľmi dobré','Bardzo dobrze','Muy Bueno','Velmi dobré'] , value='Very Good', inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['Skvělá volba','Dobrze','Bueno','Buono','Dobré','Bom','Skvělé'] , value='Good', inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['Priemer','Média','Çok iyi'] , value='Average', inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['Průměr','Promedio','Ortalama','Muito Bom','İyi'] , value='Poor', inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['Baik','Biasa','Media','Sangat Baik'] , value='Very Poor', inplace=True)
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3510988980.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3510988980.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3510988980.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3510988980.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3510988980.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3510988980.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
raw_df['RATING_TYPE'].value_counts()
# Out:
# RATING_TYPE
# Average      5115
# Good         4347
# Very Good    1148
# Excellent      96
# Poor           57
# Very Poor       4
# Name: count, dtype: int64

# %% [markdown]
# # Working on 'REGION' Column

# %%
raw_df['REGION'].value_counts()
# Out:
# REGION
# Mira Road                            405
# Malad West                           308
# Chembur                              277
# Kharghar                             268
# Borivali West                        264
#                                     ...
# Hotel Emerald-- Juhu                   1
# Trident-- Bandra Kurla Complex         1
# Sea Princess-- Juhu                    1
# Aureole Hotel-- Andheri East           1
# Hotel Satkar Residency-- Majiwada      1
# Name: count, Length: 237, dtype: int64

# %%
raw_df['REGION']=raw_df['REGION'].str.replace('[a-zA-Z].+-- ','',regex=True)
raw_df['REGION']
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\2412052723.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0        Bandra Kurla Complex
# 1                       Mahim
# 2                        Juhu
# 3        Bandra Kurla Complex
# 4        Bandra Kurla Complex
#                  ...
# 15075            Andheri West
# 15076          Kandivali West
# 15077             Lower Parel
# 15078          Kandivali West
# 15079              Malad West
# Name: REGION, Length: 10767, dtype: object

# %%
# Removing the West & East from the Region column
raw_df['REGION'] = raw_df['REGION'].str.replace(' West| west| East| east','',regex=True)
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\756905238.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
raw_df['REGION'].value_counts()
# Out:
# REGION
# Thane                726
# Mira Road            412
# Andheri              409
# Malad                378
# Kandivali            377
#                     ...
# Flea Bazaar Café       3
# Majiwada               3
# Panvel                 2
# CBD Belapur            1
# Girgaon Chowpatty      1
# Name: count, Length: 101, dtype: int64

# %%
# Replacing Small regions with Known region name
raw_df['REGION'] = raw_df['REGION'].str.replace('4 Bungalows|7 Andheri|Azad Nagar|Near Andheri Station|Veera Desai Area','Andheri',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Bandra Kurla Complex','Bandra',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('CBD-Belapur','CBD Belapur',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Girgaon Chowpatty','Chowpatty',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Dadar Shivaji Park','Dadar',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Flea Bazaar Café|Kamala Mills Compound','Lower Parel',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Runwal Green','Mulund',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Mumbai CST Area','Mumbai Central',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Kopar Khairane|Seawoods|Turbhe|Ulwe','Navi Mumbai',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('New Panvel|Old Panvel','Panvel',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Kamothe','Sion',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Ghodbunder Road|Majiwada','Thane',regex=True)


raw_df['REGION'].value_counts()
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3420027847.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3420027847.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3420027847.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3420027847.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3420027847.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3420027847.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3420027847.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3420027847.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3420027847.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3420027847.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3420027847.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19156\3420027847.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# REGION
# Thane           770
# Andheri         765
# Mira Road       412
# Malad           378
# Kandivali       377
#                ...
# Malabar Hill     14
# Sewri            12
# Alibaug          10
# Gorai             7
# Peddar Road       4
# Name: count, Length: 80, dtype: int64

# %% [markdown]
# # Removing Duplicate Record

# %%
# Finding all the duplicate rows
raw_df[raw_df.duplicated()]
# Out:
#                                 NAME   PRICE  \
# 4064   Sai Sannidhi Restaurant & Bar  1000.0
# 4068                    Konkan Katta   400.0
# 4082                  Usmaniya Hotel   600.0
# 4083                    Gina's Cakes   450.0
# 4084          Konkanastha Lunch Home   400.0
# ...                              ...     ...
# 14200      Mezbaan Family Restaurant   350.0
# 14204               Jyoti Lunch Home   650.0
# 14253                        On Toes   900.0
# 14761                    Frosty Farm   400.0
# 14928               Shree Manu Sagar   300.0
#
#                             CUSINE_CATEGORY     REGION     CUSINE TYPE  \
# 4064                    North Indian,Konkan    Dahisar   Casual Dining
# 4068          Seafood,Maharashtrian,Malwani   Mahakali     Quick Bites
# 4082                                Mughlai       Fort   Casual Dining
# 4083                                 Bakery  Dombivali            none
# 4084                        Seafood,Malwani    Chakala   Casual Dining
# ...                                     ...        ...             ...
# 14200                       Chinese,Mughlai     Mumbra           Dhaba
# 14204  Chinese,North Indian,Seafood,Mughlai     Mulund   Casual Dining
# 14253          Italian,North Indian,Chinese      Malad   Casual Dining
# 14761          Ice Cream,Desserts,Fast Food      Malad  Dessert Parlor
# 14928           North Indian,Chinese,Indian   Ghansoli     Quick Bites
#
#                                        TIMING RATING_TYPE  RATING  VOTES  \
# 4064              11am to 12midnight(Mon-Sun)        Good     3.7     99
# 4068   11am to 330pm,630pm to 1130pm(Mon-Sun)        Good     3.5    181
# 4082                1030am to 1130pm(Mon-Sun)     Average     3.2      8
# 4083                    11am to 11pm(Mon-Sun)        Good     3.5     49
# 4084   12noon to 3pm,730pm to 1030pm(Mon-Sun)        Good     3.5     44
# ...                                       ...         ...     ...    ...
# 14200               12noon to 1230AM(Mon-Sun)     Average     2.8     97
# 14204                 11am to 1230AM(Mon-Sun)        Good     3.5     49
# 14253    12noon to 3pm,7pm to 1230AM(Mon-Sun)        Good     3.6     76
# 14761                  1pm to 1215AM(Mon-Sun)        Good     3.6    120
# 14928  1130am to 415pm,7pm to 1215AM(Mon-Sun)     Average     3.3     51
#
#                               Timing DAYS_OPEN
# 4064              11am to 12midnight   Mon-Sun
# 4068   11am to 330pm,630pm to 1130pm   Mon-Sun
# 4082                1030am to 1130pm   Mon-Sun
# 4083                    11am to 11pm   Mon-Sun
# 4084   12noon to 3pm,730pm to 1030pm   Mon-Sun
# ...                              ...       ...
# 14200               12noon to 1230AM   Mon-Sun
# 14204                 11am to 1230AM   Mon-Sun
# 14253    12noon to 3pm,7pm to 1230AM   Mon-Sun
# 14761                  1pm to 1215AM   Mon-Sun
# 14928  1130am to 415pm,7pm to 1215AM   Mon-Sun
#
# [220 rows x 11 columns]

# %%
# Dropping all the duplicate rows
raw_df = raw_df.drop_duplicates()

# %% [markdown]
# # Copying the cleaned data into a new DataFrame

# %%
zomato_df = raw_df.copy()

# %%
zomato_df.head()
# Out:
#              NAME   PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200.0  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400.0                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800.0                                      Asian,Chinese
# 3  Butterfly High  1000.0                                      Modern Indian
# 4       BKC  DIVE  1200.0                   North Indian,Chinese,Continental
#
#    REGION     CUSINE TYPE                    TIMING RATING_TYPE  RATING  \
# 0  Bandra   Casual Dining  12noon to 130am(Mon-Sun)   Excellent     4.9
# 1   Mahim  Dessert Parlor       2pm to 1am(Mon-Sun)   Very Good     4.4
# 2    Juhu   Casual Dining    12noon to 1am(Mon-Sun)   Very Good     4.2
# 3  Bandra             Bar  12noon to 130am(Mon-Sun)   Very Good     4.3
# 4  Bandra             Bar    1130am to 1am(Mon-Sun)   Very Good     4.4
#
#    VOTES           Timing DAYS_OPEN
# 0   3529  12noon to 130am   Mon-Sun
# 1   1723       2pm to 1am   Mon-Sun
# 2    337    12noon to 1am   Mon-Sun
# 3   1200  12noon to 130am   Mon-Sun
# 4   5995    1130am to 1am   Mon-Sun

# %% [markdown]
# # Performing Exploratory Data Analysis

# %% [markdown]
# # Q1) How many restaurants are in Mumbai for each type of cuisine?

# %%
zomato_df['CUSINE TYPE'].value_counts()
# Out:
# CUSINE TYPE
# Casual Dining     4107
# Quick Bites       3540
# none              1127
# Bakery             537
# Dessert Parlor     431
# Café               320
# Sweet Shop         123
# Beverage Shop       91
# Food Court          50
# Bar                 47
# Dhaba               38
# Fine Dining         35
# Food Truck          30
# Lounge              27
# Pub                 17
# Kiosk               13
# Paan Shop            6
# Confectionery        3
# Bhojanalya           2
# Microbrewery         1
# Irani Cafe           1
# Mess                 1
# Name: count, dtype: int64

# %% [markdown]
# #pip install -U kaleido

# %%
fig= px.histogram(zomato_df, x='CUSINE TYPE', color='CUSINE TYPE',
                  title= 'No. of Restaurants by Cuisine Type',
                  labels={'CUSINE TYPE':'Cuisine Type'})
fig.show()

# %% [markdown]
# # Q2) What are the percentage of restaurants by Rating Type in Mumbai?

# %%
rating_type_df=zomato_df['RATING_TYPE'].value_counts().reset_index()
rating_type_df.rename(columns={'index':'RATING_TYPE', 'RATING_TYPE':'COUNT OF RESTAURANTS'}, inplace=True)
rating_type_df

# %% [markdown]
# fig = px.pie(rating_type_df, names='COUNT OF RESTAURANTS', values='count', color='COUNT OF RESTAURANTS',
#              title='Percentage of Restaurants by Rating Type').update_traces(textposition='inside', textinfo='percent+label')
# fig.show()

# %% [markdown]
# # Q3) Which are the Top 10 highest rated Seafood Restaurant in Mumbai?

# %%
seafood_df=zomato_df[zomato_df['CUSINE_CATEGORY'].str.contains('Seafood')]
seafood_df.sort_values(by='RATING',ascending=False).head(10)

# %% [markdown]
# # Q4) Which is the best Food Truck in Mumbai?

# %%
foodtruck_df=zomato_df[zomato_df['CUSINE_CATEGORY']=='Food Truck']
foodtruck.sort_values(by='RATING',ascending=False).head(2)

# %% [markdown]
# # Q5) Which places have the highest rated restaurant for each Cuisine Type in Mumbai?

# %%
highest_rated_df = zomato_df[zomato_df['RATING'] >= 4.5]
highest_rated_df1

# %% [markdown]
# # Q6) What is the Avg Price Distibution of highest rated restaurant for each Cuisine Type in Mumbai?

# %%
highest_rated_price_df = highest_rated_df.groupby(by=['REGION', 'CUSINE TYPE'])['PRICE'].mean().reset_index()
highest_rated_price_df.head()

# %% [markdown]
# # Q7) Which areas have a large number of Chinese Restaurant Market?

# %%
chinese_df = zomato_df[zomato_df['CUSINE_CATEGORY'].str.contains('Chinese')]
chinese_df

# %%
chinese_rest_df = chinese_df.groupby(by='REGION').agg({'NAME' : 'count', 'PRICE' : 'mean'}).rename(columns= {'NAME' : 'chinese_rest_df' = chinese_rest_df.sort_values('COUNT OF RESTAURANTS', ascending=False).head(25)}
chinese_rest_df.head()

# %%
fig = px.bar(chinese_rest_df, x='REGION', y='COUNT OF RESTAURANTS', color='PRICE', title= 'No. of Chinese Restaurant by Region')
fig.show()

# %% [markdown]
# # Q8) Is there a relation between Price and Rating by each Cuisine Type?

# %%
price_rating_df = zomato_df.groupby(['CUSINE TYPE', 'RATING'])['PRICE'].mean().reset_index()
price_rating_df

# %%
fig = px.line(price_rating_df, y="PRICE", x="RATING",color='CUSINE TYPE')
fig.show()

# %% [markdown]
# # Q9) Is there a relation between Region and Price?

# %%
region_price_df = zomato_df.groupby(['REGION'])['PRICE'].mean().reset_index()
region_price_df

# %%
fig = px.scatter(region_price_df, x="REGION", y="PRICE").update_traces(marker_size=8)
fig.show()

# %% [markdown]
# # Q10) Find the list of Affordable Restaurants?
# The criteria for Affordable Restaurants would be:-
# 1) Low Price
# 2) High Rated
# First step will be to find the restaurants with average cost 1/4th the average cost of most expensive restaurant in our dataframe.
# Let me explain:-The most expensive restaurant has an average meal cost= 6000. We'll try to stay economical and only pick the
# restaurants that are 1/4th of 6000.

# %%
max_price = zomato_df['PRICE'].max()
one_fourth_price = max_price/4
one_fourth_price

# %%
Finding list of restaurants that have price less than and equal to 1/4th of the max price i.e Finding Cheap Restauran
aff_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE']]
aff_rest_df = aff_rest_df[aff_rest_df['PRICE'] <= 1250]
aff_rest_df.sort_values(by='PRICE', inplace=True)
aff_rest_df

# %%
highrate_aff_df = pd.merge(aff_rest_df, highrate_rest_df, how='inner', on=['NAME', 'REGION'])
highrate_aff_df = highrate_aff_df[['NAME', 'PRICE_x', 'CUSINE_CATEGORY_x', 'REGION', 'CUSINE TYPE_x']]
highrate_aff_df.rename(columns={'NAME':'NAME', 'PRICE_x':'PRICE', 'CUSINE_CATEGORY_x':'CUSINE_CATEGORY',
                                'REGION':'REGION', 'CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)

highrate_aff_df

# %% [markdown]
# # Q10) Find the list of most Reliable Restaurants?
# The criteria for most Reliable Restaurants would be:-
# 1) Low Price
# 2) High Rated
# 3) Large No. of Votes
# First step will be to find the restaurants with Votes greater than Mean of Votes

# %%
mean_votes = zomato_df['VOTES'].mean()
mean_votes

# %%
#Finding list of restaurants that have Votes greater than and equal to Mean of Vote
mean_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE', 'VOTES']]
mean_rest_df = mean_rest_df[mean_rest_df['VOTES'] > 177]
mean_rest_df.sort_values(by='VOTES', inplace=True)
mean_rest_df

# %%
reliable_rest_df = pd.merge(mean_rest_df, highrate_aff_df, how='inner', on=['NAME', 'REGION'])
reliable_rest_df = reliable_rest_df[['NAME', 'PRICE_x', 'CUSINE_CATEGORY_x', 'REGION', 'CUSINE TYPE_x']]
reliable_rest_df.rename(columns={'NAME':'NAME', 'PRICE_x':'PRICE', 'CUSINE_CATEGORY_x':'CUSINE_CATEGORY',
                                 'REGION':'REGION', 'CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)

reliable_rest_df

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio
import plotly.express as px

# %%
data=pd.read_csv('Zomato_Mumbai_Dataset.csv', delimiter='|')
data
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15076  Hari Om Snack Bar   350
# 15077           PitaBurg   400
# 15078     Uncha Otlawala   300
# 15079     Mandarin Panda   400
# 15080                     NaN
#
#                                          CUSINE_CATEGORY    CITY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...  Mumbai
# 1                           Desserts,Ice Cream,Beverages  Mumbai
# 2                                          Asian,Chinese  Mumbai
# 3                                          Modern Indian  Mumbai
# 4                       North Indian,Chinese,Continental  Mumbai
# ...                                                  ...     ...
# 15076                     Fast Food,South Indian,Chinese  Mumbai
# ...

# %%
data.head()
# Out:
#              NAME PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800                                      Asian,Chinese
# 3  Butterfly High  1000                                      Modern Indian
# 4       BKC  DIVE  1200                   North Indian,Chinese,Continental
#
#      CITY                                             REGION  \
# 0  Mumbai  First International Financial Centre-- Bandra ...
# 1  Mumbai                                              Mahim
# 2  Mumbai                                               Juhu
# 3  Mumbai                               Bandra Kurla Complex
# 4  Mumbai                               Bandra Kurla Complex
#
#                                                  URL PAGE NO     CUSINE TYPE  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15081 entries, 0 to 15080
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             15081 non-null  object
#  1   PRICE            15080 non-null  object
#  2   CUSINE_CATEGORY  15079 non-null  object
#  3   CITY             15080 non-null  object
#  4   REGION           15080 non-null  object
#  5   URL              15080 non-null  object
#  6   PAGE NO          15080 non-null  object
#  7   CUSINE TYPE      15080 non-null  object
#  8   TIMING           15015 non-null  object
#  9   RATING_TYPE      14070 non-null  object
#  10  RATING           15080 non-null  object
#  11  VOTES            15080 non-null  object
# dtypes: object(12)
# memory usage: 1.4+ MB

# %%
data.isna().sum()
# Out:
# NAME                  0
# PRICE                 1
# CUSINE_CATEGORY       2
# CITY                  1
# REGION                1
# URL                   1
# PAGE NO               1
# CUSINE TYPE           1
# TIMING               66
# RATING_TYPE        1011
# RATING                1
# VOTES                 1
# dtype: int64

# %%
data.shape
# Out:
# (15081, 12)

# %% [markdown]
# # Pre-processing

# %%
unwanted=data['CITY']!='Mumbai'
data.loc[unwanted]
data=data[~unwanted]

# %%
data.drop(['CITY','URL','PAGE NO'],axis=1,inplace=True)
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\1636396078.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['CITY','URL','PAGE NO'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (14138, 9)

# %%
data.isnull().sum()
# Out:
# NAME                  0
# PRICE                 0
# CUSINE_CATEGORY       1
# REGION                0
# CUSINE TYPE           0
# TIMING               65
# RATING_TYPE        1010
# RATING                0
# VOTES                 0
# dtype: int64

# %%
data[data['CUSINE_CATEGORY'].isnull()]
# Out:
#                 NAME PRICE CUSINE_CATEGORY   REGION CUSINE TYPE  \
# 7338  Mother's Taste   400             NaN  Bhandup        none
#
#                      TIMING RATING_TYPE RATING VOTES
# 7338  11am to 11pm(Mon-Sun)        Good    3.5    57

# %%
data[data['TIMING'].isnull()]
# Out:
#                            NAME PRICE  \
# 919             Uncle's Kitchen   300
# 1045            Westside Bistro   500
# 1569               Delta 9 Cafe  1000
# 2984             Burger Station   300
# 3399               Bingo Burger   300
# ...                         ...   ...
# 14472             Punjab Street   700
# 14914                  MomoMaza   200
# 14972             Punjabi Tadka   300
# 14987  New Good Luck Restaurant     0
# 14995     Station England Foods   500
#
#                                   CUSINE_CATEGORY                     REGION  \
# 919                                       Chinese                 Malad West
# 1045              Italian,Mexican,Beverages,Pizza        Khopat-- Thane West
# 1569   Continental,Chinese,North Indian,Beverages        Khopat-- Thane West
# 2984                                    Fast Food  Near Andheri West Station
# 3399                             Burger,Fast Food                  Mira Road
# ...

# %%
data.fillna('NA',inplace=True)
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\2774846732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.fillna('NA',inplace=True)

# %%
data.isna().sum()
# Out:
# NAME               0
# PRICE              0
# CUSINE_CATEGORY    0
# REGION             0
# CUSINE TYPE        0
# TIMING             0
# RATING_TYPE        0
# RATING             0
# VOTES              0
# dtype: int64

# %%
data['RATING'].value_counts()
# Out:
# RATING
# -          2360
# 3.5        1094
# 3.4        1036
# 3.6         960
# NEW         953
# 3.3         926
# 3.7         917
# 3.2         801
# 3.8         782
# 3.1         734
# 3.0         622
# 3.9         596
# 2.9         409
# 4.0         408
# 2.8         309
# 4.1         298
# 4.2         199
# 2.7         170
# 4.3         148
# 4.4          99
# 2.6          77
# Opening      57
# 4.5          46
# 2.5          39
# 4.6          32
# 2.4          26
# 4.7          13
# 2.3          10
# 2.1           5
# 2.2           4
# 4.8           4
# 4.9           2
# 1.8           1
# 2.0           1
# Name: count, dtype: int64

# %%
#Replacing Text values with 0
data['RATING'].replace(to_replace=['-','NEW','Opening'],value='0',inplace=True)
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\918112842.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RATING'].replace(to_replace=['-','NEW','Opening'],value='0',inplace=True)

# %%
data['VOTES'].replace(to_replace=['-','NEW','Opening'],value='0',inplace=True)
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\1596054450.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['VOTES'].replace(to_replace=['-','NEW','Opening'],value='0',inplace=True)

# %%
data['RATING']=data['RATING'].astype('float64')
data['VOTES']=data['VOTES'].astype('int64')
data['PRICE']=data['PRICE'].astype('int64')
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\452481247.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RATING']=data['RATING'].astype('float64')
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\452481247.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['VOTES']=data['VOTES'].astype('int64')
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\452481247.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14138 entries, 0 to 15079
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             14138 non-null  object
#  1   PRICE            14138 non-null  int64
#  2   CUSINE_CATEGORY  14138 non-null  object
#  3   REGION           14138 non-null  object
#  4   CUSINE TYPE      14138 non-null  object
#  5   TIMING           14138 non-null  object
#  6   RATING_TYPE      14138 non-null  object
#  7   RATING           14138 non-null  float64
#  8   VOTES            14138 non-null  int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 1.1+ MB

# %%
data['TIMING'].value_counts()
# Out:
# TIMING
# 11am to 11pm(Mon-Sun)                              1192
# 11am to 12midnight(Mon-Sun)                         632
# 12noon to 12midnight(Mon-Sun)                       467
# 11am to 1130pm(Mon-Sun)                             309
# 10am to 10pm(Mon-Sun)                               267
#                                                    ...
# 1130am to 4pm,630pm to 1230AM...                      1
# 12midnight to 5am,12noon to 12midnight(Mon-Sun)       1
# 12midnight to 1230AM,12noon to 4pm,7pm to ...         1
# 12noon to 330pm,630pm to 12midnight...                1
# 8am to 11pm,12midnight to 115am(Mon-Sun)              1
# Name: count, Length: 2551, dtype: int64

# %%
time_data=data['TIMING'].str.split('(',n=1,expand=True)
time_data
# Out:
#                                      0                                 1
# 0                      12noon to 130am                          Mon-Sun)
# 1                           2pm to 1am                          Mon-Sun)
# 2                        12noon to 1am                          Mon-Sun)
# 3                      12noon to 130am                          Mon-Sun)
# 4                        1130am to 1am                          Mon-Sun)
# ...                                ...                               ...
# 15075  8am to 11pm,12midnight to 115am                          Mon-Sun)
# 15076                    11am to 230am                          Mon-Sun)
# 15077                     11am to 11pm  Mon,Tue,Wed,Thu,Sun),11am to ...
# 15078                    9am to 1230AM                          Mon-Sun)
# 15079       12noon to 330pm,7pm to 1am                          Mon-Sun)
#
# [14138 rows x 2 columns]

# %%
# Assigning columns back to the data frame

data['Timing']=time_data[0]
data['Days_open']=time_data[1]
data
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\46328517.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Timing']=time_data[0]
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\46328517.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Days_open']=time_data[1]
#                     NAME  PRICE  \
# 0                Hitchki   1200
# 1           Baba Falooda    400
# 2          Chin Chin Chu   1800
# 3         Butterfly High   1000
# 4              BKC  DIVE   1200
# ...

# %%
# Removing brackets from Days column

data['Days_open']=data['Days_open'].str.replace(')','')
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\2923009283.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Days_open']=data['Days_open'].str.replace(')','')

# %%
data.head()
# Out:
#              NAME  PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki   1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda    400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu   1800                                      Asian,Chinese
# 3  Butterfly High   1000                                      Modern Indian
# 4       BKC  DIVE   1200                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#                      TIMING  RATING_TYPE  RATING  VOTES           Timing  \
# ...

# %%
data.isna().sum()
# Out:
# NAME                 0
# PRICE                0
# CUSINE_CATEGORY      0
# REGION               0
# CUSINE TYPE          0
# TIMING               0
# RATING_TYPE          0
# RATING               0
# VOTES                0
# Timing               0
# Days_open          160
# dtype: int64

# %%
data.fillna('NA',inplace=True)
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\2774846732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.fillna('NA',inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14138 entries, 0 to 15079
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             14138 non-null  object
#  1   PRICE            14138 non-null  int64
#  2   CUSINE_CATEGORY  14138 non-null  object
#  3   REGION           14138 non-null  object
#  4   CUSINE TYPE      14138 non-null  object
#  5   TIMING           14138 non-null  object
#  6   RATING_TYPE      14138 non-null  object
#  7   RATING           14138 non-null  float64
#  8   VOTES            14138 non-null  int64
#  9   Timing           14138 non-null  object
#  10  Days_open        14138 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 1.3+ MB

# %%
#finding Restaurant whose rating/vote is 0

unwanted_data=(data['RATING']==0.0) |(data['VOTES']==0)
data[unwanted_data]
# Out:
#                                 NAME  PRICE  \
# 32     Hotel Annapoorna Refreshments    400
# 34                         Biryani 9    600
# 36                 D Fusion Flavours    350
# 39                      Nation Tadka    400
# 83              Link  Way Restaurant    500
# ...                              ...    ...
# 14998                  Foodies House      0
# 14999                       Khansama      0
# 15010        Earth Cafe @ Waterfield    800
# 15023           How About Some Cream    200
# 15046          Food And Taste Theory    800
#
#                                    CUSINE_CATEGORY  \
# 32                   Maharashtrian,Mughlai,Chinese
# 34                            Biryani,North Indian
# 36                                         Chinese
# 39     North Indian,South Indian,Chinese,Fast Food
# 83                            North Indian,Chinese
# ...                                            ...
# 14998                                      Chinese
# ...

# %%
data=data[~unwanted_data]

# %%
data['RATING_TYPE'].value_counts()
# Out:
# RATING_TYPE
# Average          5111
# Good             4330
# Very Good        1137
# Excellent          95
# Poor               47
# Veľmi dobré         6
# Skvělá volba        4
# Dobrze              4
# Bardzo dobrze       3
# Ortalama            2
# Bueno               2
# İyi                 2
# Buono               2
# Dobré               2
# Bom                 2
# Priemer             2
# Průměr              2
# Muito Bom           2
# Promedio            2
# Muy Bueno           1
# Sangat Baik         1
# Média               1
# Biasa               1
# Skvělé              1
# Baik                1
# Çok iyi             1
# Excelente           1
# Velmi dobré         1
# Media               1
# Name: count, dtype: int64

# %%
data['RATING_TYPE'].replace(to_replace=['Excelente'],value='Excellent',inplace=True)
data['RATING_TYPE'].replace(to_replace=['Veľmi dobré' ,'Bardzo dobrze','Muy Bueno'],value='Very Good',inplace=True)
data['RATING_TYPE'].replace(to_replace=['Skvělá volba','Dobrze','Buono','Bueno','Bom','Skvělé'],value='Good',inplace=True)
data['RATING_TYPE'].replace(to_replace=['Çok iyi','Priemer','Dobré','Média'],value='Average',inplace=True)
data['RATING_TYPE'].replace(to_replace=['Průměr','Promedio','İyi','Muito Bom','Ortalama'],value='Poor',inplace=True)
data['RATING_TYPE'].replace(to_replace=['Baik','Biasa','Media','Sangat Baik'],value='Very Poor',inplace=True)
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\2531252799.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RATING_TYPE'].replace(to_replace=['Excelente'],value='Excellent',inplace=True)
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\2531252799.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RATING_TYPE'].replace(to_replace=['Veľmi dobré' ,'Bardzo dobrze','Muy Bueno'],value='Very Good',inplace=True)
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\2531252799.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
data['RATING_TYPE'].value_counts()
# Out:
# RATING_TYPE
# Average        5117
# Good           4345
# Very Good      1147
# Excellent        96
# Poor             57
# Very Poor         4
# Velmi dobré       1
# Name: count, dtype: int64

# %%
data['REGION'].value_counts()
# Out:
# REGION
# Mira Road                            405
# Malad West                           308
# Chembur                              277
# Kharghar                             268
# Borivali West                        264
#                                     ...
# Hotel Emerald-- Juhu                   1
# Trident-- Bandra Kurla Complex         1
# Sea Princess-- Juhu                    1
# Aureole Hotel-- Andheri East           1
# Hotel Satkar Residency-- Majiwada      1
# Name: count, Length: 237, dtype: int64

# %%
data['REGION'].str.replace('[a-zA-Z].+-- ','')
# Out:
# 0        First International Financial Centre-- Bandra ...
# 1                                                    Mahim
# 2                                                     Juhu
# 3                                     Bandra Kurla Complex
# 4                                     Bandra Kurla Complex
#                                ...
# 15075                              Oshiwara-- Andheri West
# 15076                                       Kandivali West
# 15077                                          Lower Parel
# 15078                                       Kandivali West
# 15079                                           Malad West
# Name: REGION, Length: 10767, dtype: object

# %%
data['REGION'].str.replace('East|West|North|South','',regex=True)
# Out:
# 0        First International Financial Centre-- Bandra ...
# 1                                                    Mahim
# 2                                                     Juhu
# 3                                     Bandra Kurla Complex
# 4                                     Bandra Kurla Complex
#                                ...
# 15075                                  Oshiwara-- Andheri
# 15076                                           Kandivali
# 15077                                          Lower Parel
# 15078                                           Kandivali
# 15079                                               Malad
# Name: REGION, Length: 10767, dtype: object

# %%
data.head()
# Out:
#              NAME  PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki   1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda    400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu   1800                                      Asian,Chinese
# 3  Butterfly High   1000                                      Modern Indian
# 4       BKC  DIVE   1200                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#                      TIMING RATING_TYPE  RATING  VOTES           Timing  \
# ...

# %%
Duplicate=data.duplicated()
data[Duplicate]
# Out:
#                                 NAME  PRICE  \
# 4064   Sai Sannidhi Restaurant & Bar   1000
# 4068                    Konkan Katta    400
# 4082                  Usmaniya Hotel    600
# 4083                    Gina's Cakes    450
# 4084          Konkanastha Lunch Home    400
# ...                              ...    ...
# 14200      Mezbaan Family Restaurant    350
# 14204               Jyoti Lunch Home    650
# 14253                        On Toes    900
# 14761                    Frosty Farm    400
# 14928               Shree Manu Sagar    300
#
#                             CUSINE_CATEGORY          REGION     CUSINE TYPE  \
# 4064                    North Indian,Konkan    Dahisar East   Casual Dining
# 4068          Seafood,Maharashtrian,Malwani        Mahakali     Quick Bites
# 4082                                Mughlai            Fort   Casual Dining
# 4083                                 Bakery  Dombivali West            none
# ...

# %%
data=data[~Duplicate]

# %% [markdown]
# # Cleaned dataset

# %%
ZomatoData=data.copy()

# %%
ZomatoData.head()
# Out:
#              NAME  PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki   1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda    400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu   1800                                      Asian,Chinese
# 3  Butterfly High   1000                                      Modern Indian
# 4       BKC  DIVE   1200                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#                      TIMING RATING_TYPE  RATING  VOTES           Timing  \
# ...

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Q1) How many restaurants are in Mumbai for each type of cuisine?

# %%
ZomatoData['CUSINE TYPE'].value_counts()
# Out:
# CUSINE TYPE
# Casual Dining     4107
# Quick Bites       3540
# none              1127
# Bakery             537
# Dessert Parlor     431
# Café               320
# Sweet Shop         123
# Beverage Shop       91
# Food Court          50
# Bar                 47
# Dhaba               38
# Fine Dining         35
# Food Truck          30
# Lounge              27
# Pub                 17
# Kiosk               13
# Paan Shop            6
# Confectionery        3
# Bhojanalya           2
# Microbrewery         1
# Irani Cafe           1
# Mess                 1
# Name: count, dtype: int64

# %%
fig = px.histogram(ZomatoData, x='CUSINE TYPE', color='CUSINE TYPE',
 title= 'No. of Restaurants by Cuisine Type',
 labels={'CUSINE TYPE':'Cuisine Type'})
fig.show()

# %% [markdown]
# ## Q2) What are the percentage of restaurants by Rating Type in Mumbai?

# %%
ratingtype_data=ZomatoData['RATING_TYPE'].value_counts().reset_index()
ratingtype_data.rename(columns={'index':'RATING_TYPE', 'RATING_TYPE':'COUNT OF RESTAURANTS'}, inplace=True)
ratingtype_data
# Out:
#   COUNT OF RESTAURANTS  count
# 0              Average   4985
# 1                 Good   4261
# 2            Very Good   1144
# 3            Excellent     96
# 4                 Poor     56
# 5            Very Poor      4
# 6          Velmi dobré      1

# %%
#fig=px.pie(ratingtype_data,names='Rating Type',values='COUNT OF RESTAURANTS',color='Rating Type',title='Percentage of Restaurants wrt Rating Type ').update_traces(textposition='inside',textinfo='percent+label')
fig = px.pie(ratingtype_data, names='COUNT OF RESTAURANTS', values='count', title='Percentage of Restaurants wrt Rating Type')
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()

# %% [markdown]
# # Q3) Which are the Top 10 highest rated Seafood Restaurant in Mumbai?¶

# %%
seafoodData=ZomatoData[ZomatoData['CUSINE_CATEGORY'].str.contains("Seafood")]
seafoodData
# Out:
#                           NAME  PRICE  \
# 11                      Raasta   1200
# 18                   Cafe Maaz    350
# 24                Kasbah Grand   1400
# 76     Ceremonial Kitchen & Co   1000
# 85                      Rajyog    800
# ...                        ...    ...
# 15025  Mahesh Lunch Home & Bar    550
# 15026        Suyog Dinning Bar    600
# 15031               Shark Bite    400
# 15045                 Soul Fry   1000
# 15062       Cafe Delhi Heights   2000
#
#                                          CUSINE_CATEGORY  \
# 11     Continental,Seafood,Fast Food,Desserts,Italian...
# 18          Chinese,North Indian,Mughlai,Biryani,Seafood
# 24             North Indian,Mughlai,Chinese,Thai,Seafood
# 76            Seafood,Maharashtrian,North Indian,Chinese
# 85                          North Indian,Chinese,Seafood
# ...                                                  ...
# 15025               North Indian,Chinese,Seafood,Mughlai
# ...

# %%
seafoodData.sort_values(by="RATING",ascending=False).head(10)
# Out:
#                                           NAME  PRICE  \
# 7104                                Thangabali   1000
# 76                     Ceremonial Kitchen & Co   1000
# 13685                   Maharashtra Lunch Home    600
# 12433                          Quarter Canteen   1100
# 902    The Harbour Bay - SeaFood Kitchen & Bar   2400
# 884        Rajmanya- Seafood family restaurant    800
# 3380                                 Peco Peco    700
# 9954                        Pi Bar and Kitchen   1600
# 903                                Ferry Wharf   1500
# 915                   Monis Bar and Restaurant   1000
#
#                                          CUSINE_CATEGORY  \
# 7104      Seafood,South Indian,Mangalorean,Andhra,Kerala
# 76            Seafood,Maharashtrian,North Indian,Chinese
# 13685               Maharashtrian,Malwani,Konkan,Seafood
# 12433                       North Indian,Seafood,Chinese
# 902                                    Seafood,Beverages
# ...

# %% [markdown]
# # Q4) Which is the best Food Truck in Mumbai?

# %%
foodtruck=ZomatoData[ZomatoData['CUSINE TYPE'].str.contains('Food Truck')]
foodtruck
# Out:
#                                      NAME  PRICE  \
# 262                     Dumpling Delights    200
# 1017                      Street Food Co.    250
# 1381                        Veggies Treat    200
# 1689          Punjab Da Chullah- Bar Bank    500
# 2461                    Bombay Food Truck    500
# 2667   Pizza Al Passeggio-Pizza On The Go    200
# 3639                           Sobo Belly    400
# 4386                       Cheese On Fire    300
# 5562                  L' Dorado- Bar Bank    600
# 5568                  Phat Fork- Bar Bank    600
# 5753                    Jo Baka's Kitchen    300
# 6417                           Stoner 9t9    200
# 7922                      Honeys Delights    100
# 8188      Indigo Burger Project- Bar Bank    500
# 8935                          YummyWheels    250
# 9805                           Little Hut    250
# 10398                 The Pitch On Wheels    400
# 10469                 Rocksalt Food Truck    300
# ...

# %%
foodtruck.sort_values(by='RATING',ascending=False).head(2)
# Out:
#                    NAME  PRICE    CUSINE_CATEGORY        REGION CUSINE TYPE  \
# 262   Dumpling Delights    200              Momos  Matunga East  Food Truck
# 1017    Street Food Co.    250  Fast Food,Chinese         Virar  Food Truck
#
#                        TIMING RATING_TYPE  RATING  VOTES          Timing  \
# 262   430pm to 930pm(Mon-Sun)   Very Good     4.3    212  430pm to 930pm
# 1017      6pm to 3am(Mon-Sun)   Very Good     4.1    274      6pm to 3am
#
#      Days_open
# 262    Mon-Sun
# 1017   Mon-Sun

# %% [markdown]
# # Q5) Which places have the highest rated restaurant for each Cuisine Type in Mumbai?

# %%
topcuisineRes=ZomatoData[ZomatoData['RATING']>4.5]
topcuisineRes
# Out:
#                                      NAME  PRICE  \
# 0                                 Hitchki   1200
# 7                                 Tanatan   1500
# 9                      Plum by Bent Chair   1800
# 12                       Todi Mill Social   1400
# 50                         Spice Republic   1200
# 59                      Little West Pizza    600
# 66                         Downtown China    750
# 76                Ceremonial Kitchen & Co   1000
# 125                        Too Much Drama    600
# 149                     The Northern Vibe    300
# 196                        Culinary Tales   1200
# 202                           Dum & Curry    700
# 369                   Aquafire Restaurant   1100
# 459    Royale Masterchef Finedine and Bar   1400
# 588                            Pepper Fry    800
# 626                           Hotel Sagar    500
# 724                                 Maezo   1000
# 757                             Cookstory    700
# ...

# %%
fig = px.histogram(topcuisineRes, x='REGION', color='CUSINE TYPE',
 title= 'No. of Best Restaurant for each Cuisine Type by Places').update_xaxes(categoryorder='total descending')

fig.show()

# %% [markdown]
# # Q6) What is the Avg Price Distibution of highest rated restaurant for each Cuisine Type in Mumbai?

# %%
highest_rated_pricedis=topcuisineRes.groupby(by=['REGION','CUSINE TYPE'])['PRICE'].mean().reset_index()
highest_rated_pricedis.head()
# Out:
#                                REGION     CUSINE TYPE   PRICE
# 0                         4 Bungalows            none   350.0
# 1  Andheri Lokhandwala-- Andheri West            Café   800.0
# 2  Andheri Lokhandwala-- Andheri West   Casual Dining   750.0
# 3  Andheri Lokhandwala-- Andheri West  Dessert Parlor   300.0
# 4  Andheri Lokhandwala-- Andheri West          Lounge  1700.0

# %%
fig=px.histogram(highest_rated_pricedis,x='REGION',y='PRICE',color='CUSINE TYPE',
                 title='Avg Price Distibution of High rated restaurant for each Cuisine Type').update_xaxes(categoryorder='total descending')
fig.show()

# %% [markdown]
# # Q7) Which areas have a large number of Chinese Restaurant Market?

# %%
chinese_df=ZomatoData[ZomatoData['CUSINE_CATEGORY'].str.contains('Chinese')]
chinese_df
# Out:
#                     NAME  PRICE  \
# 0                Hitchki   1200
# 2          Chin Chin Chu   1800
# 4              BKC  DIVE   1200
# 5       Flea Bazaar Café    800
# 6         Persian Darbar   1300
# ...                  ...    ...
# 15071      Lucknow Zaika    500
# 15072     Zuha's Kitchen    400
# 15075    Tirupati Balaji    500
# 15076  Hari Om Snack Bar    350
# 15079     Mandarin Panda    400
#
#                                          CUSINE_CATEGORY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...
# 2                                          Asian,Chinese
# 4                       North Indian,Chinese,Continental
# 5      American,Asian,Street Food,North Indian,Luckno...
# 6                   Biryani,North Indian,Chinese,Mughlai
# ...                                                  ...
# 15071                               North Indian,Chinese
# 15072                       Chinese,North Indian,Mughlai
# ...

# %%
chinese_rest_df = chinese_df.groupby(by='REGION').agg ({'NAME':'count','PRICE':'mean'}).rename(columns={'NAME':'COUNT OF RESTAURANTS'}).reset_index()

chinese_rest_df.sort_values('COUNT OF RESTAURANTS',ascending=False).head(5)
# Out:
#              REGION  COUNT OF RESTAURANTS       PRICE
# 123       Mira Road                   220  545.681818
# 29          Chembur                   149  592.617450
# 113      Malad West                   142  635.563380
# 92           Kalyan                   132  520.833333
# 43   Dombivali East                   127  552.779528

# %%
fig=px.bar(chinese_rest_df,x='REGION',y='COUNT OF RESTAURANTS',color='PRICE',title='No of Chinese Restaurants by Region').update
fig.show()

# %% [markdown]
# # Q8) Is there a relation between Price and Rating by each Cuisine Type?¶

# %%
price_rating_df = ZomatoData.groupby(['CUSINE TYPE', 'RATING'])['PRICE'].mean().reset_index()
price_rating_df
# Out:
#     CUSINE TYPE  RATING       PRICE
# 0        Bakery     2.7  400.000000
# 1        Bakery     2.8  285.714286
# 2        Bakery     2.9  328.571429
# 3        Bakery     3.0  300.000000
# 4        Bakery     3.1  369.117647
# ..          ...     ...         ...
# 278        none     4.3  683.333333
# 279        none     4.4  555.000000
# 280        none     4.5  420.000000
# 281        none     4.6  687.500000
# 282        none     4.7  350.000000
#
# [283 rows x 3 columns]

# %%
fig=px.line(price_rating_df, y="PRICE", x="RATING",color='CUSINE TYPE')
fig.show()

# %% [markdown]
# # Q9) Is there a relation between Region and Price?¶

# %%
regiondata=ZomatoData.groupby(['REGION'])['PRICE'].mean().reset_index()
regiondata
# Out:
#                            REGION        PRICE
# 0                     4 Bungalows   528.787879
# 1      7 Bungalows-- Andheri West   614.285714
# 2            Abbott Hotel-- Vashi  1225.000000
# 3                          Airoli   452.287582
# 4                         Alibaug   665.000000
# ..                            ...          ...
# 232                        Wadala   427.500000
# 233     Wagle Estate-- Thane West   439.024390
# 234                         Worli   517.763158
# 235  Xperia Mall-- Dombivali East   600.000000
# 236         Yogi Midtown-- Turbhe  1800.000000
#
# [237 rows x 2 columns]

# %%
fig = px.scatter(regiondata, x="REGION", y="PRICE").update_traces(marker_size=2)
fig.show()

# %% [markdown]
# # Q10) Find the list of Affordable Restaurants?¶

# %%
max_price = ZomatoData['PRICE'].max()
one_fourth_price = max_price/4
one_fourth_price
# Out:
# 1250.0

# %%
# Finding list of restaurants that have price less than and equal to 1/4th of the max price i.e Finding Cheap Restauran
aff_rest_df = ZomatoData[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE']]
aff_rest_df = aff_rest_df[aff_rest_df['PRICE'] <= 1250]
aff_rest_df.sort_values(by='PRICE', inplace=True)
aff_rest_df
# Out:
#                                                    NAME  PRICE  \
# 6137                                 Sanjog Wine N Dine      5
# 2925                                         Jab We Eat     50
# 9598                                          Ho5 Store     50
# 9589                                   Golden Butterfly    100
# 5916                                  Madhuri Puranpoli    100
# ...                                                 ...    ...
# 2740                                     Peninsula Next   1200
# 5528                                         The Thekka   1200
# 964                                        Bijoli Grill   1250
# 6045  Fabelle at The Chocolate Boutique - ITC Grand ...   1250
# 7301                               SamBar Pub & Kitchen   1250
#
#                                         CUSINE_CATEGORY  \
# 6137                               North Indian,Chinese
# 2925  South Indian,North Indian,Maharashtrian,Fast Food
# ...

# %%
# Finding the highest rated list of restaurants
highrate_rest_df = ZomatoData[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE','RATING']]
highrate_rest_df = highrate_rest_df[highrate_rest_df['RATING'] >= 4.5]
highrate_rest_df.sort_values(by='PRICE', inplace=True)
highrate_rest_df
# Out:
#                                           NAME  PRICE  \
# 1502             Cake Centre-The Dessert Maker    150
# 763                     Curry And Combos Twist    200
# 807                               Moussestruck    200
# 14234                             Cone Culture    250
# 725                                  Belo Pops    300
# ...                                        ...    ...
# 5335                                Mia Cucina   2000
# 1786                             Global Fusion   2000
# 8887                      Drifters Tap Station   2000
# 12625                        House of Mandarin   2100
# 902    The Harbour Bay - SeaFood Kitchen & Bar   2400
#
#                                   CUSINE_CATEGORY  \
# 1502                                     Desserts
# 763                          North Indian,Chinese
# 807                                      Desserts
# 14234                                    European
# 725                  Ice Cream,Desserts,Beverages
# ...

# %%
# Now, we'll merge the aff_rest_df with highrate_rest_df to obtain the intersection
# i.e the list of Affordable Restaurants !!

# %%
highrate_aff_df = pd.merge(aff_rest_df, highrate_rest_df, how='inner', on=['NAME', 'REGION'])

# %%
highrate_aff_df = highrate_aff_df[['NAME', 'PRICE_x', 'CUSINE_CATEGORY_x', 'REGION', 'CUSINE TYPE_x']]
highrate_aff_df.rename(columns={'NAME':'NAME', 'PRICE_x':'PRICE', 'CUSINE_CATEGORY_x':'CUSINE_CATEGORY',
'REGION':'REGION', 'CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)

# %%
# Affordable Restaurants with low price and high rating
highrate_aff_df
# Out:
#                              NAME  PRICE  \
# 0   Cake Centre-The Dessert Maker    150
# 1          Curry And Combos Twist    200
# 2                    Moussestruck    200
# 3                    Cone Culture    250
# 4                     Smiley Pops    300
# ..                            ...    ...
# 60         Wild Dining Restaurant   1200
# 61                        Invento   1200
# 62                 Culinary Tales   1200
# 63                        Hitchki   1200
# 64               The Joker Bistro   1200
#
#                                       CUSINE_CATEGORY  \
# 0                                            Desserts
# 1                                North Indian,Chinese
# 2                                            Desserts
# 3                                            European
# 4               Desserts,Ice Cream,Beverages,Sandwich
# ..                                                ...
# 60           North Indian,Continental,Mexican,Chinese
# ...

# %% [markdown]
# #  Find the list of most Reliable Restaurants?

# %% [markdown]
# he criteria for most Reliable Restaurants would be:-
#
# Low Price
# High Rated
# Large No. of Votes First step will be to find the restaurants with Votes greater than Mean of Votes

# %%
mean_votes=ZomatoData['VOTES'].mean()
mean_votes
# Out:
# 177.2656679624538

# %%
largevotes=ZomatoData[['NAME','PRICE','CUSINE_CATEGORY','REGION','VOTES']]
largevotes=largevotes[largevotes['VOTES']>177]
largevotes.sort_values(by='VOTES',inplace=True)
largevotes
# Out:
#                                      NAME  PRICE  \
# 4194                  Sai Sagar Veg Treat    500
# 884   Rajmanya- Seafood family restaurant    800
# 3914                             Ice Cafe    500
# 7897                     Konkan Lajjatdar    500
# 3828     Frozen Delight -The Dessert Cafe    250
# ...                                   ...    ...
# 8539                   Leopold Cafe & Bar   1600
# 1251                         Joey's Pizza    800
# 5337         Chili's American Grill & Bar   1400
# 3751                         Prithvi Cafe    700
# 8897                              Candies    700
#
#                                         CUSINE_CATEGORY  \
# 4194  North Indian,South Indian,Chinese,Fast Food,Be...
# 884                        Maharashtrian,Konkan,Seafood
# 3914                Fast Food,Ice Cream,Beverages,Pizza
# 7897   Seafood,Biryani,Beverages,Chinese,Malwani,Konkan
# 3828                                 Desserts,Ice Cream
# ...

# %%
reliable_rest=pd.merge(largevotes, highrate_aff_df, how='inner', on=['NAME', 'REGION'])
reliable_rest
# Out:
#                                    NAME  PRICE_x  \
# 0   Rajmanya- Seafood family restaurant      800
# 1                        Fresh Food Co.      500
# 2                            Dessertino      300
# 3                               Invento     1200
# 4                Maharashtra Lunch Home      600
# 5                              Regano's      600
# 6                       Big Bang Cuurry      350
# 7                           Sandy's Den     1000
# 8                     Angrezi Patiyalaa     1200
# 9                                 Maezo     1000
# 10                         Tossin Pizza      900
# 11                    Little West Pizza      600
# 12              Ceremonial Kitchen & Co     1000
# 13                         Moussestruck      200
# 14                      Daftar Goregaon      750
# 15          Poetry By Love & Cheesecake     1000
# 16                         Makhan Singh      800
# 17                     The Joker Bistro     1200
# ...

# %%
reliable_rest=reliable_rest[['NAME', 'PRICE_x', 'CUSINE_CATEGORY_x', 'REGION', 'CUSINE TYPE']]
reliable_rest.rename(columns={'NAME':'NAME','PRICE_x':'PRICE','CUSINE_CATEGORY_x':'CUSINE_CATEGORY','REGION':'REGION','CUSINE TYPE':'CUSINE TYPE'},inplace=True)
reliable_rest
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_17756\1136857347.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                    NAME  PRICE  \
# 0   Rajmanya- Seafood family restaurant    800
# 1                        Fresh Food Co.    500
# 2                            Dessertino    300
# 3                               Invento   1200
# 4                Maharashtra Lunch Home    600
# 5                              Regano's    600
# 6                       Big Bang Cuurry    350
# 7                           Sandy's Den   1000
# 8                     Angrezi Patiyalaa   1200
# 9                                 Maezo   1000
# 10                         Tossin Pizza    900
# 11                    Little West Pizza    600
# 12              Ceremonial Kitchen & Co   1000
# ...
